# %% [markdown]
# # 📘 Visualização Exploratória Rápida com `.plot()` no Pandas
# **Tema:** Plotagem a partir de objetos Series e DataFrames
# **Base:** Titanic (Kaggle)
#
# Neste notebook, você irá explorar a base Titanic e praticar a visualização exploratória rápida (Quick EDA) com o método `.plot()` do Pandas.

# %%
# Importação de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 🛳️ Carregando a base de dados Titanic

# %%
# Carregue o arquivo 'train.csv' da base Titanic (Kaggle)
# Dica: use pd.read_csv()
df =

# %% [markdown]
# ## 🔍 Entendendo os dados

# %%
# Visualize as primeiras linhas do DataFrame

# %%
# Mostre informações gerais sobre as colunas e tipos de dados

# %%
# Gere estatísticas descritivas rápidas com o método describe()

# %%
# Verifique a presença de valores faltantes

# %% [markdown]
# ## 📈 Plotando diretamente a partir de uma Series

# %%
# Crie um histograma para a coluna 'Age' mostrando a distribuição das idades

# %%
# Crie um gráfico de barras mostrando a contagem de passageiros por classe (coluna 'Pclass')

# %% [markdown]
# ## 📊 Plotando diretamente a partir de um DataFrame

# %%
# Crie um gráfico de dispersão (scatter) mostrando a relação entre 'Age' e 'Fare'

# %%
# Crie um gráfico de linha mostrando a média da tarifa ('Fare') por classe ('Pclass')

# %% [markdown]
# ## 📦 Histogramas e Boxplots para análise estatística

# %%
# Gere um histograma da coluna 'Fare' para analisar a distribuição de tarifas

# %%
# Gere boxplots para as colunas 'Age' e 'Fare' e analise possíveis outliers

# %% [markdown]
# ## ⚖️ Comparando distribuições por grupos

# %%
# Crie um boxplot da variável 'Age' comparando passageiros que sobreviveram (coluna 'Survived') e os que não sobreviveram

# %%
# Calcule a média da tarifa ('Fare') por sexo ('Sex') e classe ('Pclass') e gere um gráfico de barras
