# %% [markdown]
# <h1><b>Exercícios - Estatística Descritiva</b></h1>

# %% [markdown]
# <h2>Exercício 1:
# <h2>

# %% [markdown]
# <p>
#     a) Tipo de vitamina (A, B1, B2, B6, B12):
#     Qualitativa -> Nominal
#
#     b) Classificação de uma lesão (fatal; severa; moderada; pequena):
#     Qualitativa -> Ordinal
#
#     c) Número de nascidos em certo hospital em jun/2017: Quantitativa -> Discreta
#
#     d) Concentração de flúor na água: Quantitativa -> Continua
# </p>
