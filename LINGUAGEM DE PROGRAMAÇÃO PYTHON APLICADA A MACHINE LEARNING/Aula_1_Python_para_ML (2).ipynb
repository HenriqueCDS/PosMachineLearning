# %% [markdown]
# ## 🎯 Tópicos - Aula 1 - Revisão Python 🎯<br>
#
# 💾 [Variáveis](#um)
#
# ↙️↘️ [Condicionais](#dois)
#
# ➿ [While](#tres)
#
# ➰ [For](#quatro)
#
# 📖 [Listas](#cinco)
#
# 📈 [Funções](#seis)
#
# 🔠 [Strings](#sete)
#
# 🔠 [Manipulação de arquivos](#oito)
#
# 🔠 [Bibliotecas](#nove)

# %% [markdown]
# ## 1️⃣ Variáveis <a class="anchor" id="um"></a>
# <br>

# %%
#Variável string
var_str = 'PUC-Campinas'
#Variável numérica inteira
var_int = 10
#Variável numérica decimal
var_float = 3.14
#Variável booleana (ou lógica)
var_bool = True

# %%
print(var_str)
# Out:
# PUC-Campinas

# %%
#Método
var_str.capitalize()
# Out:
# 'Puc-campinas'

# %%
len(var_str)
# Out:
# 12

# %% [markdown]
# Podemos também alterar o tipo de uma variável

# %%
float(var_int) #10 == 10.0
# Out:
# 10.0

# %%
float(var_int) == var_int
# Out:
# True

# %% [markdown]
# E fazer operações matemáticas:
# - Somar (+)
# - Subtrair (-)
# - Multiplicar (*)
# - Dividir (/)
# - Divisão exata (//)
# - Divisão com resto (%)
# - Potenciação (**)

# %%
var_int + var_float
# Out:
# 13.14

# %%
var_int - var_float
# Out:
# 6.859999999999999

# %%
var_int * var_float
# Out:
# 31.400000000000002

# %%
var_int / var_float
# Out:
# 3.184713375796178

# %%
var_int // 3
# Out:
# 3

# %%
var_int % 3
# Out:
# 1

# %% [markdown]
# ### input e print:

# %%
#Solicitando a idade do usuário
idade = int(input('Qual a sua idade? '))
#Imprimir uma mensagem
print(f'A sua idade é igual a {idade} anos.')
# Out:
# A sua idade é igual a 152 anos.

# %%
type(idade)
# Out:
# int

# %%
#Estruturas de dados
tupla_1 = (var_str, var_int, var_float, var_bool) #Invariável
lista_1 = [var_str, var_int, var_float, var_bool] #Variável
dicio_1 = {'Nome':'Romero',"idade":34}

# %%
tupla_1
# Out:
# ('PUC-Campinas', 10, 3.14, True)

# %%
dicio_1
# Out:
# {'Nome': 'Romero', 'idade': 34}

# %% [markdown]
# ____

# %% [markdown]
# ## 2️⃣ Condicionais <a class="anchor" id="dois"></a>
# <br>

# %% [markdown]
# ### 1) Operadores lógicos
#
# Em muitos problemas de programação, há necessidade de se fazer **comparações** entre variáveis.
#
# Por exemplo:
#
# - checar se um número é maior que outro;
# - checar se uma variável é igual a outra;
# - checar se há números diferentes; etc.
#
# Para fazer essas comparações, utilizamos os **operadores lógicos de comparação**. Em Python, há 6 desses operadores:
#
# - Maior que: >
# - Maior ou igual: >=
# - Menor que: <
# - Menor ou igual: <=
# - Igual: ==
# - Diferente: !=
#
# O resultado de uma comparação sempre vai ser um booleano, isto é, **True** ou **False**!
#
# Dica: sempre leia as comparações como uma **pergunta**

# %%
#Maior
200 > 100
# Out:
# True

# %%
#Maior ou igual
200 >= 100
# Out:
# True

# %%
#Menor
200 < 100
# Out:
# False

# %%
#Menor ou igual
200 <= 100
# Out:
# False

# %%
#Igual
200 == 100
# Out:
# False

# %%
#Igual
200 != 100
# Out:
# True

# %% [markdown]
# ### 2) Operadores Condicionais
#
# Além dos operadores lógicos de comparação, também temos os **operadores lógicos de conjunção**, que são utilizados pra fazer uma **combinação** entre comparações.
#
# Os operadores de conjunção são: **and** e **or**, e eles seguem a seguinte regra:
#
# - **and** só é True se **ambas** as comparações forem True:
#     - False and True resulta em "False"
#     - False and False resulta em "False"
#     - True and True resulta em "True"
# - **or** é True se **pelo menos uma** das comparações for True:
#     - False or True resulta em "True"
#     - True or True resulta em "True"
#     - False or False resulta em "False"

# %%
print("Operador and:")
print(False and False)
print(True and False)
print(False and True)
print(True and True)
# Out:
# Operador and:
# False
# False
# False
# True

# %%
print("Operador or:")
print(False or False)
print(False or True)
print(True or False)
print(True or True)
# Out:
# Operador or:
# False
# True
# True
# True

# %% [markdown]
# ### 3) Not e Inversão Lógica

# %%
not 3<10
# Out:
# False

# %%
idade
# Out:
# 152

# %% [markdown]
# Para alguém ser considerado digno da aposentadoria, ele precisa ter mais que 65 anos. Dado uma idade, verifique e retorne se a pessoa é digna da aposentadoria. Se não, diga a ela quanto tempo ela deverá esperar para se aposentar.

# %%
if idade >= 65:
  print('Olá, você pode se aposentar!')
else:
  print(f'Você não está apto para aposentar, ainda precisa esperar {65-idade} anos.')
# Out:
# Olá, você pode se aposentar!

# %% [markdown]
# ____

# %% [markdown]
# ## 3️⃣ While <a class="anchor" id="três"></a>
# <br>

# %% [markdown]
# Uma das utilidades de linguagens de programação é a de automatizar tarefas que são repetitivas.
#
# Mas, pra isso ser viável, seria bom se tivéssemos uma estrutura para **repetir comandos**, não é mesmo?
#
# Imagine que eu queira exibir na tela "Olá, mundo!" 5 vezes. Podemos fazer:

# %%
nomes = ['Ana', 'Jorge', 'Douglas','Rodolpho','José']

# %%
print(f'Olá, {nomes[0]}!')
print(f'Olá, {nomes[1]}!')
print(f'Olá, {nomes[2]}!')
print(f'Olá, {nomes[3]}!')
print(f'Olá, {nomes[4]}!')
# Out:
# Olá, Ana!
# Olá, Jorge!
# Olá, Douglas!
# Olá, Rodolpho!
# Olá, José!

# %% [markdown]
# Mas, e se eu quiser exibir essa mensagem 1000 vezes? Ou 1 milhão de vezes? Não é ideal escrevermos o mesmo pedaço de código tantas vezes, né?
#
# Para isso, existem os **laços de repetição**, que permitem repetir pedaços de código quantas vezes desejarmos!
#
# O primeiro laço que vamos ver é o **while**. Este laço tem a seguinte estrutura:
#
# ```python
# while (condicao é True):
#     operacao_repetida
# ```
#
# Ou seja, o que tá no bloco do while é repetido **enquanto a condição for verdadeira**:

# %%
nomes
# Out:
# ['Ana', 'Jorge', 'Douglas', 'Rodolpho', 'José']

# %%
while nomes != []:
  nome = nomes.pop(0)
  print(f'Olá, {nome}!')
# Out:
# Olá, Ana!
# Olá, Jorge!
# Olá, Douglas!
# Olá, Rodolpho!
# Olá, José!

# %% [markdown]
# ### **ATENÇÃO:**
#
# Você precisa estar atento à **condição**, pois uma condição errada pode levar a **loops infinitos**.
#
# **Veja o exemplo abaixo:**

# %%
# while == 1: #Loop infinito (FUJA)
  # print('Olá, mundo!')

# %% [markdown]
# ____

# %% [markdown]
# ## 4️⃣ For <a class="anchor" id="quatro"></a>
# <br>
#
# O `for` pode ser entendido como um operador utilizado para **percorrer elementos de uma lista** (na verdade, de qualquer objeto **iterável**. Conheceremos outros objetos assim mais pra frente...)
#
# A estrutura do for é:
#
# ```python
# for item in lista:
#     operacao_feita_pra_cada_item
# ```

# %%
for nome in nomes:
  print(f'Olá, {nome}!')

# %%
nomes
# Out:
# []

# %%
cont = len(nomes) - 1
while cont>=0:
  print(f'Olá, {nomes[cont]}!')
  cont -= 1

# %%
cont = 0
while cont<=len(nomes) - 1:
  print(f'Olá, {nomes[cont]}!')
  cont += 1

# %% [markdown]
# ____

# %% [markdown]
# ## 5️⃣ Listas <a class="anchor" id="cinco"></a>
# <br>
#
# Imagine que você quer armazenar várias variáveis relacionadas, como, por exemplo, todas suas notas em provas.
#
# Se houver muitas notas, não é muito prático criar uma variável para cada uma. Seria muito mais conveniente armazenar todas as notas em uma **lista**, não é mesmo?
#
# Em python, temos uma estrutura de dados que é exatamente isso: uma lista! Listas são indicadas por colchete []
#
# Uma lista nada mais é que um **conjunto de objetos**, que podem ser de diversos tipos:

# %% [markdown]
# Principais métodos e atributos:

# %%
lista_1
# Out:
# ['PUC-Campinas', 10, 3.14, True]

# %%
#Append: adicionar um valor ao final da lista
lista_1.append(1)

# %%
lista_1
# Out:
# ['PUC-Campinas', 10, 3.14, True, 1]

# %%
#Pop: remove o último valor da lista
lista_1.pop()
# Out:
# 1

# %%
lista_1
# Out:
# ['PUC-Campinas', 10, 3.14, True]

# %%
lista_1.insert(1,1)

# %%
lista_1
# Out:
# ['PUC-Campinas', 1, 10, 3.14, True]

# %%
lista_1[:2]
# Out:
# ['PUC-Campinas', 1]

# %%
lista_1[3:]
# Out:
# [3.14, True]

# %%
lista_1[-2:]
# Out:
# [3.14, True]

# %%
#Lista de frutas
lista_frutas = ['mamão', 'abacaxi', 'laranja', 'pera']

# %%
sorted(lista_frutas)
# Out:
# ['abacaxi', 'laranja', 'mamão', 'pera']

# %%
lista_frutas
# Out:
# ['mamão', 'abacaxi', 'laranja', 'pera']

# %%
lista_frutas.sort()

# %%
lista_frutas
# Out:
# ['abacaxi', 'laranja', 'mamão', 'pera']

# %%
[1,2,3] + [4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista_num = [1,2,3]

# %%
lista_num.extend([4,5,6])

# %%
lista_num
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
lista_frutas.remove('laranja')

# %%
lista_frutas
# Out:
# ['abacaxi', 'mamão', 'pera']

# %%
lista_frutas.reverse()

# %%
lista_frutas
# Out:
# ['pera', 'mamão', 'abacaxi']

# %%
lista_frutas.index('mamão')
# Out:
# 1

# %%
lista_num = [7, 8.5, 9]
media = sum(lista_num) / len(lista_num)

# %%
media
# Out:
# 8.166666666666666

# %% [markdown]
# ____

# %% [markdown]
# ## 6️⃣ Funções <a class="anchor" id="seis"></a>
# <br>
#
#
# A intuição sobre funções, então, já nos é familiar:
#
# Uma função é um objeto utilizado para **fazer determinadas ações**.
#
# Podemos ver uma função como uma "caixinha" que pega uma **entrada** (o argumento), faz algum **processamento**, e então **retorna uma saída** (o output)
#
# <img src="https://s3.amazonaws.com/illustrativemathematics/images/000/000/782/medium/Task_1_8c7a6a9a2e1421586c40f125bd783de3.jpg?1335065782" width=300>
#
#
# <img src="https://1.bp.blogspot.com/_MhOt9n2UJbM/TC6emeqHdqI/AAAAAAAAAiQ/1brsWuWvOC0/s1600/function-machine.png" width=300>

# %% [markdown]
# A estrutura de **definição de uma função** é dada por:
#
# ```python
# def nome_da_funcao(argumento1, argumento2, ...):
#
#     instrucoes
#
#     return saida
# ```

# %% [markdown]
# Há 5 elementos fundamentais para a criação de novas funções em Python:
#
# - Primeiramente, usamos "def" para deixar claro que estamos **definindo** uma função;
# - Depois, damos um **nome** para nossa função;
# - Em parênteses, falamos quais serão os **argumentos** da função -- esses são os inputs, e em python, esses elementos são opcionais!
# - Depois, explicitamos qual é o **processamento** feito pela função;
# - Ao fim, dizemos o que a função irá **retornar** -- esses são os outputs, e em Python esse elemento é opcional!

# %%
#Função cumprimenta
def cumprimenta(nome, hora):
  if hora < 12:
    return f'Bom dia, {nome}!'
  elif hora < 18:
    return f'Boa tarde, {nome}!'
  else:
    return f'Boa noite, {nome}!'

# %%
cumprimenta(hora = 20, nome = 'Romero')
# Out:
# 'Boa noite, Romero!'

# %% [markdown]
# ____

# %% [markdown]
# ## 7️⃣ Strings <a class="anchor" id="sete"></a>
# <br>

# %% [markdown]
# Concatenação:

# %%
nome = 'Romero'
sobrenome1 = 'Florentino'
sobrenome2 = 'de Carvalho'

# %%
nome + ' ' + sobrenome1 + ' ' + sobrenome2
# Out:
# 'Romero Florentino de Carvalho'

# %% [markdown]
# Métodos

# %%
#Definindo uma string
mensagem = '                                       Bem-vindo de volta à Pós-Graduação da PUC-Campinas!              '

# %% [markdown]
# ### Capitalize:
#
# Retorna uma cópia da string com o primeiro caractere em maiúsculo e os demais em minúsculo.

# %%
mensagem.capitalize()
# Out:
# '                                       bem-vindo de volta à pós-graduação da puc-campinas!              '

# %% [markdown]
# ### Lower:
#
# Retorna uma cópia da string com todos os caracteres em minúsculo.

# %%
mensagem.lower()
# Out:
# '                                       bem-vindo de volta à pós-graduação da puc-campinas!              '

# %% [markdown]
# ### Upper:
#
# Retorna uma cópia da string com todos os caracteres em maiúsculo.

# %%
mensagem.upper()
# Out:
# '                                       BEM-VINDO DE VOLTA À PÓS-GRADUAÇÃO DA PUC-CAMPINAS!              '

# %% [markdown]
# ### Swapcase:
#
# Retorna uma cópia da string com a capitalização dos caracteres invertida.

# %%
mensagem.swapcase()
# Out:
# '                                       bEM-VINDO DE VOLTA À pÓS-gRADUAÇÃO DA puc-cAMPINAS!              '

# %% [markdown]
# ### Title:
#
# Retorna uma cópia da string com o primeiro caractere de cada palavra em maiúsculo.

# %%
mensagem.title()
# Out:
# '                                       Bem-Vindo De Volta À Pós-Graduação Da Puc-Campinas!              '

# %% [markdown]
# ### Strip:
#
# Retorna uma cópia da string sem espaços em branco no início e no fim.

# %%
mensagem.strip()
# Out:
# 'Bem-vindo de volta à Pós-Graduação da PUC-Campinas!'

# %% [markdown]
# Temos a lstrip para espaços à esquerda (início) e rstrip à direita (fim).

# %%
mensagem = 'Bem-vindo de volta à Pós-Graduação da PUC-Campinas!'

# %% [markdown]
# ### Split:
#
# Divide a string em substrings com base em um separador e retorna uma lista contendo essas substrings.

# %%
mensagem.split()
# Out:
# ['Bem-vindo', 'de', 'volta', 'à', 'Pós-Graduação', 'da', 'PUC-Campinas!']

# %% [markdown]
# ### join:
#
# Concatena os elementos de um iterável (por exemplo, uma lista) em uma string, usando a string como separador entre os elementos.

# %%
nomes
# Out:
# []

# %%
string_nova = ', '.join(nomes)

# %%
string_nova
# Out:
# ''

# %% [markdown]
# ### Replace:
#
# Retorna uma cópia da string em que todas as ocorrências de um determinado caractere ou sequência de caracteres são substituídas por outro caractere ou sequência de caracteres.

# %%
mensagem
# Out:
# 'Bem-vindo de volta à Pós-Graduação da PUC-Campinas!'

# %%
mensagem.replace('a','@')
# Out:
# 'Bem-vindo de volt@ à Pós-Gr@du@ção d@ PUC-C@mpin@s!'

# %% [markdown]
# ### Count:
#
# Conta o número de ocorrências de uma determinada substring na string.

# %%
mensagem.count('a')
# Out:
# 6

# %% [markdown]
# ### Função len:
#
# Determina o tamanho da string.

# %%
len(mensagem)
# Out:
# 51

# %% [markdown]
# Slicing

# %%
mensagem[:5]
# Out:
# 'Bem-v'

# %%
mensagem[-4:]
# Out:
# 'nas!'

# %% [markdown]
# ____

# %% [markdown]
# ## 8️⃣ Manipulação de arquivos <a class="anchor" id="oito"></a>
# <br>

# %% [markdown]
# ### **Arquivos txt**
#
# Todos os programas que fizemos até o momento tinham variáveis, input e output **temporários**, guardados na memória RAM do computador **enquanto o programa é executado**.
#
# Após o programa ser finalizado, todas as variáveis, inputs e outputs eram perdidos.
#
# Muitas vezes queremos que esses valores sejam armazenados, que os dados processados pelo programa sejam preservados. O termo para esta característica é **persistência de dados**.
#
# A persistência se dá através de **arquivos**: documentos criados para **armazenar dados em uma memória permanente**, como o **disco rígido**, um **USB** ou um **servidor web**.

# %% [markdown]
# O Python têm algumas funções padrão para a manipulação de arquivos. Vamos vê-las!

# %% [markdown]
# A função `open()` é usada pra abrir arquivos existentes ou criar um arquivo novo.
#
# O primeiro argumento a ser passado é o caminho do arquivo, com seu nome (se apenas o nome do arquivo for passado, isso é interpretado como o arquivo estando na mesma pasta que o código!); e o segundo é o modo de operação. Os modos são:
#
# - `r` -	lê um arquivo existente
# - `w` -	cria um novo arquivo ou sobrescreve um existente
# - `a` -	cria um novo arquivo ou adiciona informações ao seu final (append)
# - `+` -	ao ser combinado com outros modos, permite alteração de arquivo já existente (ex: `r+` abre um arquivo existente e permite modificá-lo)
#
# O argumento de **modo de operação não é obrigatório** e o Python assume o `r` como **default**.
#
# O terceiro argumento é o "encoding", que dá a codificação do arquivo.
# O encoding é a representação dos caracteres no qual é atribuído um número diferente para cada um. Pra evitar problemas, é legal sempre usar `encoding="utf-8"`

# %% [markdown]
# Uma vez aberto o arquivo, podemos escrever alguma coisa nele. Para isso, usamos a função `write()`
#
# Essa função aceita apenas um argumento, que é o que você quer escrever no arquivo

# %%
arquivo = open('ola.txt', 'w', encoding = 'utf-8')

# %%
arquivo
# Out:
# <_io.TextIOWrapper name='ola.txt' mode='w' encoding='utf-8'>

# %%
arquivo.write('Olá, mundo!!!')
arquivo.write('Sejam bem-vindos de volta, alunos da PUC-Campinas!')
# Out:
# 50

# %% [markdown]
# Após abrirmos (ou criarmos) um arquivo, e fazer as operações desejadas com ele, devemos fechá-lo usando a função `close()`. Essa etapa é importante por 2 motivos:
#
# - Se alteramos o arquivo mas não o fechamos, as alterações não serão salvas.
# - Se esquecermos de fechar um arquivo, outros programas podem ter problemas de acesso a ele.
#
# Por isso, **nunca se esqueca de fechar os arquivos abertos!**

# %%
arquivo.close()

# %% [markdown]
# __Fazendo todas as operações em uma única célula__

# %%
arquivo = open('ola.txt', 'w', encoding = 'utf-8')
arquivo.write('Olá, mundo!!!\n')
arquivo.write('Sejam bem-vindos de volta, alunos da PUC-Campinas!')
arquivo.close()

# %% [markdown]
# Como o arquivo já existe, vamos tentar ler com o modo "r"...

# %%
arquivo = open('ola.txt', 'r', encoding = 'utf-8')
arquivo.read()
# Out:
# 'Olá, mundo!!!\nSejam bem-vindos de volta, alunos da PUC-Campinas!'

# %% [markdown]
# Repare que os textos foram considerados como pertencentes a mesma linha. Para que ele interprete as linhas separadamente precisamos finalizar com um caracter especial denominado **EOL (End of Line)** como o `\n`. Eles indicam que a linha atual acabou e o início de uma nova linha.

# %% [markdown]
# Quando usamos arquivo.write(), o Python apenas adiciona o texto que fornecido, um após o outro, sem nenhum espaço ou quebra de linha por padrão.
#
# No seu código original, a segunda string "Sejam bem-vindos..." foi escrita imediatamente depois da primeira, resultando em uma única linha contínua no arquivo.
#
# **Como resolver?** Lendo linha por linha:

# %%
with open('ola.txt', 'r', encoding = 'utf-8') as arquivo:
  for linha in arquivo:
    print(linha)
# Out:
# Olá, mundo!!!
#
# Sejam bem-vindos de volta, alunos da PUC-Campinas!

# %% [markdown]
# **Obs.:** O with já faz o papel de abrir e fechar o arquivo.

# %% [markdown]
# ### **Arquivos CSV**
#
# Um tipo de arquivo muito comum é o **csv**
#
# A sigla CSV significa **Comma-Separated Values**, ou **"valores separados por vírgula"**.
#
# Este formato é uma forma padrão de representar tabelas usando arquivos de texto simples: cada elemento é separado por uma vírgula (ou ponto-e-vírgula, ou, qualquer outro separador), e cada linha é separada por uma quebra de linha.

# %% [markdown]
# ____

# %% [markdown]
# Em Python, podemos entender um arquivo CSV como uma lista de listas.
#
# Imagine que queremos armazenar um arquivo csv. Começamos com uma lista de listas:

# %% [markdown]
# Pode não ser tão simples escrever esta lista de listas em um arquivo usando a função write(), como vimos antes, né?
#
# Para trabalhar com arquivos csv, vamos utilizar a biblioteca `csv` do python!
#
# Desta biblioteca, vamo usar duas funções:
#
# - **função de escrita**: `csv.writer().writerows()`
#
# - **função de leitura**: `csv.reader()`

# %% [markdown]
# __Vamos agora processar esse arquivo que acabamos de ler?__
#
# Imagina que queremos calcular qual é a média de determinado aluno, a partir do seu nome!
#
# Com a função `index()` em um **list comprehension** podemos encontrar qual a posição na lista de determinado aluno:

# %% [markdown]
# Por exemplo, o aluno "Han", está na posição de índice 2:
#
# *   Item da lista
# *   Item da lista

# %% [markdown]
# Agora, basta passar esse índice para a lista de listas (que chamamos de
#
# *   Item da lista
# *   Item da lista
#
# "planilha"), pra acessarmos a linha correspondente ao Han:

# %% [markdown]
# Legal! Agora, sabemos que as posições de índice 1 e 2 **desta lista** são, respectivamente, a nota1 e a nota2!
#
# Ou seja, podemos capturar as notas (já as transformando para float!), e aí calcular a média

# %% [markdown]
# Vamos agora fazer todas as operações acima, mas solicitando ao usuário a média de qual aluno ele deseja:

# %% [markdown]
# É possíver fazer o **processamento de arquivos** de forma muito mais simples e natural do que foi feito acima, ao utilizarmos uma biblioteca própria para isso: o [pandas](https://pandas.pydata.org/)!

# %% [markdown]
# ## 9️⃣ Bibliotecas <a class="anchor" id="nove"></a>
# <br>

# %% [markdown]
# O **[Pandas](https://pandas.pydata.org/)** é uma das bibliotecas mais usadas em data science.
#
# Esta biblioteca, construída a partir do Numpy, possibilita a estruturação e manipulação de dados de maneira simples e eficiente.
#
# Como os dados são a matéria prima de todo projeto de Data Science, manipulá-los é fundamental! Por isso, utilizaremos o Pandas em quase todas as aulas daqui pra frente!

# %% [markdown]
# [Guia do pandas](https://pandas.pydata.org/docs/user_guide/index.html#user-guide)
